# %%
# %run ./demo.py
# Out:
# image = /dataset/omon_masked.jpg
# faces_count = 5
# - [0]
# face = 3b8ea8dadc9c719e6cabb9e82f57c2ff
# gender = Male
# age = 35
# face_rectangle = {
#     "width": 28,
#     "top": 242,
#     "height": 28,
#     "left": 820
# }
# - [1]
# face = 5919d85dafe7fed03f969bd1a73756ce
# gender = Male
# age = 38
# face_rectangle = {
#     "width": 26,
#     "top": 229,
#     "height": 26,
#     "left": 180
# }
# - [2]
# face = d7c366adc3c31696a46b64cdca795d0f
# gender = Male
# age = 25
# face_rectangle = {
#     "width": 26,
#     "top": 211,
#     "height": 26,
#     "left": 409
# }
# - [3]
# face = 69acc285f83370334a0c8a6b60324f19
# gender = Male
# age = 28
# face_rectangle = {
#     "width": 24,
#     "top": 238,
#     "height": 24,
#     "left": 717
# }
# - [4]
# face = 368f1c9b982ec921b6caa7f27a915908
# gender = Male
# age = 35
# face_rectangle = {
#     "width": 19,
#     "top": 290,
#     "height": 19,
#     "left": 109
# }

# %%
from IPython.display import Image 
pil_img = Image(filename='omon_masked_out.png')
display(pil_img)
